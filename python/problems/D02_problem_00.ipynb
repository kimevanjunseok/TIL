# %% [markdown]
# # 가상화폐 시세 판단하기

# %% [markdown]
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
# |Key Name        |     Description|
# |---|---|
# |opeing_price    |최근 24시간 내 시작 거래금액|
# |closing_price   |최근 24시간 내 마지막 거래금액|
# |min_price       |최근 24시간 내 최저 거래금액|
# |max_price       |최근 24시간 내 최고 거래금액|

# %%
import requests
from pprint import pprint
btc = requests.get('https://api.bithumb.com/public/ticker/btc').json()['data']
pprint(btc)
# Out:
# {'24H_fluctate': '-45000',
#  '24H_fluctate_rate': '-1.04',
#  'average_price': '4300915.729',
#  'buy_price': '4277000',
#  'closing_price': '4278000',
#  'date': '1546568922109',
#  'max_price': '4339000',
#  'min_price': '4250000',
#  'opening_price': '4323000',
#  'sell_price': '4278000',
#  'units_traded': '18058.50336827',
#  'volume_1day': '18058.50336827',
#  'volume_7day': '56224.25563717'}

# %%
# 아래에 코드를 작성하세요.
money = float(btc['opening_price'])
change = float(btc['max_price']) - float(btc['min_price'])
deff = money + change
if deff > int(btc['max_price']):
    print('상승장')
else:
    print('하락장')
# Out:
# 상승장

# %% [markdown]
# ## 모든 가상화폐 시세 판단하기
#
#
# > currrency dictionary에 담겨있는 모든 가상화폐 거래내역을 바탕으로 출력하라.
# >
# > 예외 처리에 유의하세요.
#
#
#
# ```
# 예시 출력)
# BTC 상승장
# ETH 상승장
# DASH 상승장
# LTC 하락장
# ETC 하락장
# XRP 상승장
# BCH 상승장
# ...
# ```

# %%
currency = requests.get('https://api.bithumb.com/public/ticker/all').json()['data']
pprint(currency)
# Out:
# {'ABT': {'24H_fluctate': '-9.6',
#          '24H_fluctate_rate': '-9.14',
#          'average_price': '103.1858',
#          'buy_price': '95.4',
#          'closing_price': '95.4',
#          'max_price': '115',
#          'min_price': '94.1',
#          'opening_price': '105',
#          'sell_price': '96.2',
#          'units_traded': '11281415.94651732',
#          'volume_1day': '11281415.94651732',
#          'volume_7day': '50710599.971695697921657788'},
#  'ADA': {'24H_fluctate': '-1.5',
#          '24H_fluctate_rate': '-1.92',
#          'average_price': '77.1534',
#          'buy_price': '76.2',
#          'closing_price': '76.3',
#          'max_price': '79.3',
#          'min_price': '75.1',
#          'opening_price': '77.8',
#          'sell_price': '76.3',
#          'units_traded': '2104431.36115746',
#          'volume_1day': '2104431.36115746',
#          'volume_7day': '39724502.04226205'},
#  'ADD': [],
#  'AE': {'24H_fluctate': '-35',
#         '24H_fluctate_rate': '-2.12',
#         'average_price': '1632.2266',
#         'buy_price': '1602',
#         'closing_price': '1610',
#         'max_price': '1678',
#         'min_price': '1600',
#         'opening_price': '1645',
#         'sell_price': '1610',
#         'units_traded': '64531.42505548',
#         'volume_1day': '64531.42505548',
#         'volume_7day': '1896227.301237726162182133'},
#  'AMO': {'24H_fluctate': '-0.19',
#          '24H_fluctate_rate': '-10.67',
#          'average_price': '1.6927',
#          'buy_price': '1.58',
#          'closing_price': '1.59',
#          'max_price': '1.78',
#          'min_price': '1.56',
#          'opening_price': '1.78',
#          'sell_price': '1.59',
#          'units_traded': '697377134.90658575',
#          'volume_1day': '697377134.90658575',
#          'volume_7day': '24142491541.322695320725033356'},
#  'BAT': {'24H_fluctate': '-2',
#          '24H_fluctate_rate': '-1.34',
#          'average_price': '147.005',
#          'buy_price': '146',
#          'closing_price': '147',
#          'max_price': '154',
#          'min_price': '144',
#          'opening_price': '149',
#          'sell_price': '147',
#          'units_traded': '1420816.50549052',
#          'volume_1day': '1420816.50549052',
#          'volume_7day': '7016174.909410630100902915'},
#  'BCD': {'24H_fluctate': '-41',
#          '24H_fluctate_rate': '-3.97',
#          'average_price': '1014.4658',
#          'buy_price': '991',
#          'closing_price': '990',
#          'max_price': '1040',
#          'min_price': '990',
#          'opening_price': '1031',
#          'sell_price': '1002',
#          'units_traded': '124538.70205646',
#          'volume_1day': '124538.70205646',
#          'volume_7day': '1809169.96207988'},
#  'BCH': {'24H_fluctate': '-10500',
#          '24H_fluctate_rate': '-5.51',
#          'average_price': '183668.0558',
#          'buy_price': '179600',
#          'closing_price': '180000',
#          'max_price': '191500',
#          'min_price': '177300',
#          'opening_price': '190500',
#          'sell_price': '180000',
#          'units_traded': '45886.09037662',
#          'volume_1day': '45886.09037662',
#          'volume_7day': '551066.10568314'},
#  'BHPC': {'24H_fluctate': '-9',
#           '24H_fluctate_rate': '-0.99',
#           'average_price': '909.514',
#           'buy_price': '894',
#           'closing_price': '898',
#           'max_price': '927',
#           'min_price': '890',
#           'opening_price': '907',
#           'sell_price': '898',
#           'units_traded': '496049.78255765',
#           'volume_1day': '496049.78255765',
#           'volume_7day': '8367318.318785793158754071'},
#  'BLACK': [],
#  'BSV': {'24H_fluctate': '-3900',
#          '24H_fluctate_rate': '-3.77',
#          'average_price': '100353.4796',
#          'buy_price': '99300',
#          'closing_price': '99500',
#          'max_price': '103800',
#          'min_price': '97400',
#          'opening_price': '103400',
#          'sell_price': '99500',
#          'units_traded': '23425.34962066',
#          'volume_1day': '23425.34962066',
#          'volume_7day': '269110.53616854'},
#  'BTC': {'24H_fluctate': '-46000',
#          '24H_fluctate_rate': '-1.06',
#          'average_price': '4300581.9141',
#          'buy_price': '4271000',
#          'closing_price': '4275000',
#          'max_price': '4339000',
#          'min_price': '4250000',
#          'opening_price': '4321000',
#          'sell_price': '4275000',
#          'units_traded': '18064.50183981',
#          'volume_1day': '18064.50183981',
#          'volume_7day': '56226.44811031'},
#  'BTG': {'24H_fluctate': '-340',
#          '24H_fluctate_rate': '-2.30',
#          'average_price': '14457.9146',
#          'buy_price': '14400',
#          'closing_price': '14410',
#          'max_price': '14970',
#          'min_price': '12970',
#          'opening_price': '14750',
#          'sell_price': '14490',
#          'units_traded': '24076480.44533701',
#          'volume_1day': '24076480.44533701',
#          'volume_7day': '102565224.50514794'},
#  'BZNT': {'24H_fluctate': '-0.09',
#           '24H_fluctate_rate': '-0.35',
#           'average_price': '27.9271',
#           'buy_price': '27.9',
#           'closing_price': '28.1',
#           'max_price': '29.3',
#           'min_price': '27',
#           'opening_price': '28.2',
#           'sell_price': '28.1',
#           'units_traded': '35161896.33343007',
#           'volume_1day': '35161896.33343007',
#           'volume_7day': '192340679.955433452831885565'},
#  'CHL': [],
#  'CMT': {'24H_fluctate': '-0.2',
#          '24H_fluctate_rate': '-0.57',
#          'average_price': '34.5328',
#          'buy_price': '34',
#          'closing_price': '34.6',
#          'max_price': '36.2',
#          'min_price': '32.4',
#          'opening_price': '34.8',
#          'sell_price': '34.5',
#          'units_traded': '4509685.97875042',
#          'volume_1day': '4509685.97875042',
#          'volume_7day': '35922130.816895702860476475'},
#  'CTXC': {'24H_fluctate': '-4',
#           '24H_fluctate_rate': '-3.36',
#           'average_price': '117.9907',
#           'buy_price': '115',
#           'closing_price': '115',
#           'max_price': '124',
#           'min_price': '113',
#           'opening_price': '119',
#           'sell_price': '117',
#           'units_traded': '1321899.12641294',
#           'volume_1day': '1321899.12641294',
#           'volume_7day': '11464019.268621014673753123'},
#  'DASH': {'24H_fluctate': '-3000',
#           '24H_fluctate_rate': '-3.21',
#           'average_price': '90551.7419',
#           'buy_price': '90300',
#           'closing_price': '90300',
#           'max_price': '93500',
#           'min_price': '88100',
#           'opening_price': '93300',
#           'sell_price': '90550',
#           'units_traded': '3563073.23363308',
#           'volume_1day': '3563073.23363308',
#           'volume_7day': '32309743.81502674'},
#  'ELF': {'24H_fluctate': '5',
#          '24H_fluctate_rate': '3.87',
#          'average_price': '132.3273',
#          'buy_price': '134',
#          'closing_price': '134',
#          'max_price': '139',
#          'min_price': '125',
#          'opening_price': '129',
#          'sell_price': '135',
#          'units_traded': '5180478.0034298',
#          'volume_1day': '5180478.0034298',
#          'volume_7day': '18476954.211566113183667368'},
#  'ENJ': {'24H_fluctate': '-1.2',
#          '24H_fluctate_rate': '-2.70',
#          'average_price': '43.9959',
#          'buy_price': '42.9',
#          'closing_price': '43.1',
#          'max_price': '45.7',
#          'min_price': '42.6',
#          'opening_price': '44.3',
#          'sell_price': '43.3',
#          'units_traded': '3356518.37599568',
#          'volume_1day': '3356518.37599568',
#          'volume_7day': '22969202.292858192816118614'},
#  'EOS': {'24H_fluctate': '-135',
#          '24H_fluctate_rate': '-4.31',
#          'average_price': '3044.6324',
#          'buy_price': '2991',
#          'closing_price': '2995',
#          'max_price': '3166',
#          'min_price': '2930',
#          'opening_price': '3130',
#          'sell_price': '2995',
#          'units_traded': '2388905.24628913',
#          'volume_1day': '2388905.24628913',
#          'volume_7day': '22662405.88522839'},
#  'EOSDAC': [],
#  'ETC': {'24H_fluctate': '-255',
#          '24H_fluctate_rate': '-4.28',
#          'average_price': '5774.2929',
#          'buy_price': '5680',
#          'closing_price': '5690',
#          'max_price': '5995',
#          'min_price': '5640',
#          'opening_price': '5945',
#          'sell_price': '5690',
#          'units_traded': '530328.58689124',
#          'volume_1day': '530328.58689124',
#          'volume_7day': '1863788.024714439873039559'},
#  'ETH': {'24H_fluctate': '-3000',
#          '24H_fluctate_rate': '-1.76',
#          'average_price': '168097.4852',
#          'buy_price': '167100',
#          'closing_price': '167100',
#          'max_price': '173800',
#          'min_price': '163500',
#          'opening_price': '170100',
#          'sell_price': '167200',
#          'units_traded': '579836.72422476',
#          'volume_1day': '579836.72422476',
#          'volume_7day': '1972392.868621668123877503'},
#  'ETHOS': {'24H_fluctate': '-18',
#            '24H_fluctate_rate': '-1.61',
#            'average_price': '1107.6775',
#            'buy_price': '1094',
#            'closing_price': '1095',
#            'max_price': '1177',
#            'min_price': '1050',
#            'opening_price': '1113',
#            'sell_price': '1095',
#            'units_traded': '255440.30497046',
#            'volume_1day': '255440.30497046',
#            'volume_7day': '6292462.32765914'},
#  'GNT': {'24H_fluctate': '-1.8',
#          '24H_fluctate_rate': '-2.32',
#          'average_price': '76.4727',
#          'buy_price': '75.6',
#          'closing_price': '75.6',
#          'max_price': '77.8',
#          'min_price': '75.3',
#          'opening_price': '77.4',
#          'sell_price': '76',
#          'units_traded': '1035043.07700724',
#          'volume_1day': '1035043.07700724',
#          'volume_7day': '37287483.872657287038279961'},
#  'GTO': {'24H_fluctate': '-1.1',
#          '24H_fluctate_rate': '-1.50',
#          'average_price': '74.0707',
#          'buy_price': '72',
#          'closing_price': '72',
#          'max_price': '78.1',
#          'min_price': '71.2',
#          'opening_price': '73.1',
#          'sell_price': '72.9',
#          'units_traded': '2280325.52872207',
#          'volume_1day': '2280325.52872207',
#          'volume_7day': '24857918.56665879'},
#  'HC': {'24H_fluctate': '-9',
#         '24H_fluctate_rate': '-0.62',
#         'average_price': '1444.4229',
#         'buy_price': '1413',
#         'closing_price': '1431',
#         'max_price': '1512',
#         'min_price': '1380',
#         'opening_price': '1440',
#         'sell_price': '1431',
#         'units_traded': '81255.13893315',
#         'volume_1day': '81255.13893315',
#         'volume_7day': '882569.41417459'},
#  'HORUS': [],
#  'ICX': {'24H_fluctate': '1',
#          '24H_fluctate_rate': '0.34',
#          'average_price': '294.8774',
#          'buy_price': '286',
#          'closing_price': '290',
#          'max_price': '318',
#          'min_price': '281',
#          'opening_price': '289',
#          'sell_price': '290',
#          'units_traded': '2162361.40936089',
#          'volume_1day': '2162361.40936089',
#          'volume_7day': '5066469.357227308297395376'},
#  'INS': {'24H_fluctate': '39',
#          '24H_fluctate_rate': '12.03',
#          'average_price': '340.3862',
#          'buy_price': '363',
#          'closing_price': '363',
#          'max_price': '366',
#          'min_price': '316',
#          'opening_price': '324',
#          'sell_price': '364',
#          'units_traded': '4295512.3617694',
#          'volume_1day': '4295512.3617694',
#          'volume_7day': '11871270.8729124444'},
#  'IOST': {'24H_fluctate': '-0.06',
#           '24H_fluctate_rate': '-0.92',
#           'average_price': '6.3297',
#           'buy_price': '6.39',
#           'closing_price': '6.4',
#           'max_price': '6.52',
#           'min_price': '6.16',
#           'opening_price': '6.46',
#           'sell_price': '6.4',
#           'units_traded': '423562255.79133556',
#           'volume_1day': '423562255.79133556',
#           'volume_7day': '1445966083.458134314024641302'},
#  'ITC': {'24H_fluctate': '-2',
#          '24H_fluctate_rate': '-1.43',
#          'average_price': '136.6727',
#          'buy_price': '135',
#          'closing_price': '137',
#          'max_price': '141',
#          'min_price': '133',
#          'opening_price': '139',
#          'sell_price': '137',
#          'units_traded': '1490137.17329136',
#          'volume_1day': '1490137.17329136',
#          'volume_7day': '17483861.196962838287319066'},
#  'KNC': {'24H_fluctate': '-6',
#          '24H_fluctate_rate': '-3.29',
#          'average_price': '179.4103',
#          'buy_price': '176',
#          'closing_price': '176',
#          'max_price': '185',
#          'min_price': '173',
#          'opening_price': '182',
#          'sell_price': '177',
#          'units_traded': '804423.76485387',
#          'volume_1day': '804423.76485387',
#          'volume_7day': '7200398.210890646089975132'},
#  'LINK': {'24H_fluctate': '58',
#           '24H_fluctate_rate': '15.89',
#           'average_price': '403.9592',
#           'buy_price': '420',
#           'closing_price': '423',
#           'max_price': '446',
#           'min_price': '362',
#           'opening_price': '365',
#           'sell_price': '423',
#           'units_traded': '12435668.11535239',
#           'volume_1day': '12435668.11535239',
#           'volume_7day': '16815910.951125832613136453'},
#  'LOOM': {'24H_fluctate': '-1.6',
#           '24H_fluctate_rate': '-2.84',
#           'average_price': '57.6969',
#           'buy_price': '54.3',
#           'closing_price': '54.7',
#           'max_price': '63.8',
#           'min_price': '53.1',
#           'opening_price': '56.3',
#           'sell_price': '54.7',
#           'units_traded': '23359213.29002164',
#           'volume_1day': '23359213.29002164',
#           'volume_7day': '46787153.767599057015732253'},
#  'LRC': {'24H_fluctate': '-34',
#          '24H_fluctate_rate': '-5.77',
#          'average_price': '575.9182',
#          'buy_price': '555',
#          'closing_price': '555',
#          'max_price': '595',
#          'min_price': '555',
#          'opening_price': '589',
#          'sell_price': '558',
#          'units_traded': '145447.56128059',
#          'volume_1day': '145447.56128059',
#          'volume_7day': '2934894.483971617643527395'},
#  'LTC': {'24H_fluctate': '-1020',
#          '24H_fluctate_rate': '-2.78',
#          'average_price': '35919.6791',
#          'buy_price': '35600',
#          'closing_price': '35600',
#          'max_price': '36920',
#          'min_price': '34940',
#          'opening_price': '36620',
#          'sell_price': '35670',
#          'units_traded': '11822.58119976',
#          'volume_1day': '11822.58119976',
#          'volume_7day': '176032.35822017'},
#  'MCO': {'24H_fluctate': '-21',
#          '24H_fluctate_rate': '-0.80',
#          'average_price': '2583.3714',
#          'buy_price': '2581',
#          'closing_price': '2590',
#          'max_price': '2637',
#          'min_price': '2533',
#          'opening_price': '2611',
#          'sell_price': '2622',
#          'units_traded': '804621.66880361',
#          'volume_1day': '804621.66880361',
#          'volume_7day': '1917169.83707829'},
#  'MEETONE': [],
#  'MITH': {'24H_fluctate': '-2.4',
#           '24H_fluctate_rate': '-3.37',
#           'average_price': '69.8277',
#           'buy_price': '68.8',
#           'closing_price': '68.8',
#           'max_price': '71.4',
#           'min_price': '68.3',
#           'opening_price': '71.2',
#           'sell_price': '69',
#           'units_traded': '9110085.37870668',
#           'volume_1day': '9110085.37870668',
#           'volume_7day': '106223679.38890550599621313'},
#  'OCN': {'24H_fluctate': '-0.15',
#          '24H_fluctate_rate': '-3.76',
#          'average_price': '3.8415',
#          'buy_price': '3.77',
#          'closing_price': '3.83',
#          'max_price': '4.03',
#          'min_price': '3.67',
#          'opening_price': '3.98',
#          'sell_price': '3.81',
#          'units_traded': '55835372.2925736',
#          'volume_1day': '55835372.2925736',
#          'volume_7day': '1599017957.117881341205216652'},
#  'OMG': {'24H_fluctate': '-16',
#          '24H_fluctate_rate': '-0.95',
#          'average_price': '1644.8905',
#          'buy_price': '1640',
#          'closing_price': '1654',
#          'max_price': '1678',
#          'min_price': '1612',
#          'opening_price': '1670',
#          'sell_price': '1655',
#          'units_traded': '1241887.41404469',
#          'volume_1day': '1241887.41404469',
#          'volume_7day': '10923825.502421818906013623'},
#  'PAY': {'24H_fluctate': '-77',
#          '24H_fluctate_rate': '-4.26',
#          'average_price': '1786.5316',
#          'buy_price': '1730',
#          'closing_price': '1730',
#          'max_price': '1845',
#          'min_price': '1730',
#          'opening_price': '1807',
#          'sell_price': '1739',
#          'units_traded': '187447.02630496',
#          'volume_1day': '187447.02630496',
#          'volume_7day': '8335390.245679065051907765'},
#  'PIVX': {'24H_fluctate': '-45',
#           '24H_fluctate_rate': '-4.63',
#           'average_price': '938.9786',
#           'buy_price': '926',
#           'closing_price': '926',
#           'max_price': '972',
#           'min_price': '914',
#           'opening_price': '971',
#           'sell_price': '927',
#           'units_traded': '143404.67200544',
#           'volume_1day': '143404.67200544',
#           'volume_7day': '10432784.24314645'},
#  'PLY': {'24H_fluctate': '-1.5',
#          '24H_fluctate_rate': '-3.81',
#          'average_price': '38.0876',
#          'buy_price': '37.6',
#          'closing_price': '37.8',
#          'max_price': '40',
#          'min_price': '36.4',
#          'opening_price': '39.3',
#          'sell_price': '37.8',
#          'units_traded': '9390434.8613848',
#          'volume_1day': '9390434.8613848',
#          'volume_7day': '108913418.307038524'},
#  'POLY': {'24H_fluctate': '-5',
#           '24H_fluctate_rate': '-3.10',
#           'average_price': '157.2423',
#           'buy_price': '155',
#           'closing_price': '156',
#           'max_price': '162',
#           'min_price': '155',
#           'opening_price': '161',
#           'sell_price': '157',
#           'units_traded': '1139107.89719114',
#           'volume_1day': '1139107.89719114',
#           'volume_7day': '9947173.169597255355654461'},
#  'POWR': {'24H_fluctate': '-18',
#           '24H_fluctate_rate': '-3.32',
#           'average_price': '528.622',
#           'buy_price': '519',
#           'closing_price': '523',
#           'max_price': '545',
#           'min_price': '512',
#           'opening_price': '541',
#           'sell_price': '523',
#           'units_traded': '415474.36745944',
#           'volume_1day': '415474.36745944',
#           'volume_7day': '6093304.15676919'},
#  'PPT': {'24H_fluctate': '-38',
#          '24H_fluctate_rate': '-2.25',
#          'average_price': '1661.3995',
#          'buy_price': '1647',
#          'closing_price': '1648',
#          'max_price': '1691',
#          'min_price': '1621',
#          'opening_price': '1686',
#          'sell_price': '1668',
#          'units_traded': '36368.2578',
#          'volume_1day': '36368.2578',
#          'volume_7day': '689441.44646665'},
#  'PST': {'24H_fluctate': '-5',
#          '24H_fluctate_rate': '-4.38',
#          'average_price': '111.4954',
#          'buy_price': '109',
#          'closing_price': '109',
#          'max_price': '117',
#          'min_price': '107',
#          'opening_price': '114',
#          'sell_price': '110',
#          'units_traded': '817437.91146885',
#          'volume_1day': '817437.91146885',
#          'volume_7day': '9442421.040711780616582618'},
#  'QTUM': {'24H_fluctate': '-86',
#           '24H_fluctate_rate': '-3.35',
#           'average_price': '2494.2457',
#           'buy_price': '2479',
#           'closing_price': '2479',
#           'max_price': '2567',
#           'min_price': '2449',
#           'opening_price': '2565',
#           'sell_price': '2480',
#           'units_traded': '745477.62373422',
#           'volume_1day': '745477.62373422',
#           'volume_7day': '3113167.87475229'},
#  'RDN': {'24H_fluctate': '-39',
#          '24H_fluctate_rate': '-11.78',
#          'average_price': '311.3054',
#          'buy_price': '292',
#          'closing_price': '292',
#          'max_price': '345',
#          'min_price': '279',
#          'opening_price': '331',
#          'sell_price': '294',
#          'units_traded': '7236483.83633444',
#          'volume_1day': '7236483.83633444',
#          'volume_7day': '25604654.181105808601343468'},
#  'REP': {'24H_fluctate': '-2800',
#          '24H_fluctate_rate': '-2.85',
#          'average_price': '96864.6176',
#          'buy_price': '95500',
#          'closing_price': '95400',
#          'max_price': '99300',
#          'min_price': '94800',
#          'opening_price': '98200',
#          'sell_price': '96050',
#          'units_traded': '3599.59565605',
#          'volume_1day': '3599.59565605',
#          'volume_7day': '93963.848581661535728315'},
#  'RNT': {'24H_fluctate': '-11',
#          '24H_fluctate_rate': '-7.48',
#          'average_price': '145.4128',
#          'buy_price': '135',
#          'closing_price': '136',
#          'max_price': '183',
#          'min_price': '116',
#          'opening_price': '147',
#          'sell_price': '136',
#          'units_traded': '83514001.09196093',
#          'volume_1day': '83514001.09196093',
#          'volume_7day': '187904323.687717765839833516'},
#  'ROM': {'24H_fluctate': '-0.01',
#          '24H_fluctate_rate': '-7.69',
#          'average_price': '0.1264',
#          'buy_price': '0.12',
#          'closing_price': '0.12',
#          'max_price': '0.13',
#          'min_price': '0.12',
#          'opening_price': '0.13',
#          'sell_price': '0.13',
#          'units_traded': '42682738274.07092308',
#          'volume_1day': '42682738274.07092308',
#          'volume_7day': '217201558023.912943198764699686'},
#  'SALT': {'24H_fluctate': '-11',
#           '24H_fluctate_rate': '-4.01',
#           'average_price': '273.36',
#           'buy_price': '263',
#           'closing_price': '263',
#           'max_price': '289',
#           'min_price': '262',
#           'opening_price': '274',
#           'sell_price': '266',
#           'units_traded': '1398099.25691115',
#           'volume_1day': '1398099.25691115',
#           'volume_7day': '12800350.93135121'},
#  'SNT': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '116.4948',
#          'buy_price': '115',
#          'closing_price': '116',
#          'max_price': '120',
#          'min_price': '112',
#          'opening_price': '116',
#          'sell_price': '116',
#          'units_traded': '1673077.04033482',
#          'volume_1day': '1673077.04033482',
#          'volume_7day': '23691484.733549516667242801'},
#  'STEEM': {'24H_fluctate': '-41',
#            '24H_fluctate_rate': '-2.23',
#            'average_price': '1824.9681',
#            'buy_price': '1795',
#            'closing_price': '1795',
#            'max_price': '1875',
#            'min_price': '1784',
#            'opening_price': '1836',
#            'sell_price': '1803',
#            'units_traded': '76761.3415933',
#            'volume_1day': '76761.3415933',
#            'volume_7day': '1363421.2645473'},
#  'STRAT': {'24H_fluctate': '-50',
#            '24H_fluctate_rate': '-1.75',
#            'average_price': '2842.1284',
#            'buy_price': '2800',
#            'closing_price': '2800',
#            'max_price': '2919',
#            'min_price': '2751',
#            'opening_price': '2850',
#            'sell_price': '2862',
#            'units_traded': '24078.13949972',
#            'volume_1day': '24078.13949972',
#            'volume_7day': '486243.1355285'},
#  'THETA': {'24H_fluctate': '-1.3',
#            '24H_fluctate_rate': '-2.25',
#            'average_price': '57.9709',
#            'buy_price': '56.1',
#            'closing_price': '56.3',
#            'max_price': '62.8',
#            'min_price': '55.4',
#            'opening_price': '57.6',
#            'sell_price': '56.3',
#            'units_traded': '18464555.0409032',
#            'volume_1day': '18464555.0409032',
#            'volume_7day': '91468129.437188079266342968'},
#  'TMTG': {'24H_fluctate': '-0.31',
#           '24H_fluctate_rate': '-3.70',
#           'average_price': '8.2416',
#           'buy_price': '8.04',
#           'closing_price': '8.05',
#           'max_price': '8.41',
#           'min_price': '8.02',
#           'opening_price': '8.36',
#           'sell_price': '8.06',
#           'units_traded': '207094184.3603097',
#           'volume_1day': '207094184.3603097',
#           'volume_7day': '1491054798.006375034973863815'},
#  'TRUE': {'24H_fluctate': '19',
#           '24H_fluctate_rate': '6.46',
#           'average_price': '307.1851',
#           'buy_price': '311',
#           'closing_price': '313',
#           'max_price': '337',
#           'min_price': '287',
#           'opening_price': '294',
#           'sell_price': '313',
#           'units_traded': '2442086.84053346',
#           'volume_1day': '2442086.84053346',
#           'volume_7day': '8945553.288065135701278979'},
#  'TRX': {'24H_fluctate': '0.4',
#          '24H_fluctate_rate': '1.80',
#          'average_price': '22.4357',
#          'buy_price': '22.3',
#          'closing_price': '22.5',
#          'max_price': '23.2',
#          'min_price': '21.8',
#          'opening_price': '22.1',
#          'sell_price': '22.5',
#          'units_traded': '222992496.50920231',
#          'volume_1day': '222992496.50920231',
#          'volume_7day': '936128539.0481994'},
#  'VET': {'24H_fluctate': '-0.29',
#          '24H_fluctate_rate': '-3.94',
#          'average_price': '7.1896',
#          'buy_price': '7.07',
#          'closing_price': '7.06',
#          'max_price': '7.35',
#          'min_price': '7.06',
#          'opening_price': '7.35',
#          'sell_price': '7.13',
#          'units_traded': '7931982.36053304',
#          'volume_1day': '7931982.36053304',
#          'volume_7day': '72285653.23316151956123794'},
#  'WAVES': {'24H_fluctate': '-7',
#            '24H_fluctate_rate': '-0.20',
#            'average_price': '3484.291',
#            'buy_price': '3446',
#            'closing_price': '3459',
#            'max_price': '3550',
#            'min_price': '3419',
#            'opening_price': '3466',
#            'sell_price': '3476',
#            'units_traded': '171529.90951167',
#            'volume_1day': '171529.90951167',
#            'volume_7day': '2673513.43270588'},
#  'WAX': {'24H_fluctate': '-2',
#          '24H_fluctate_rate': '-1.86',
#          'average_price': '105.5833',
#          'buy_price': '105',
#          'closing_price': '105',
#          'max_price': '108',
#          'min_price': '104',
#          'opening_price': '107',
#          'sell_price': '106',
#          'units_traded': '830540.56469347',
#          'volume_1day': '830540.56469347',
#          'volume_7day': '17384084.07220036'},
#  'WET': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '14.0778',
#          'buy_price': '13.9',
#          'closing_price': '14',
#          'max_price': '14.4',
#          'min_price': '13.9',
#          'opening_price': '14',
#          'sell_price': '14',
#          'units_traded': '18815686.35738711',
#          'volume_1day': '18815686.35738711',
#          'volume_7day': '193756886.698309116950969508'},
#  'WTC': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '1285.2622',
#          'buy_price': '1258',
#          'closing_price': '1268',
#          'max_price': '1328',
#          'min_price': '1253',
#          'opening_price': '1268',
#          'sell_price': '1273',
#          'units_traded': '233587.77937532',
#          'volume_1day': '233587.77937532',
#          'volume_7day': '2373316.279517056649794688'},
#  'XEM': {'24H_fluctate': '-0.3',
#          '24H_fluctate_rate': '-0.41',
#          'average_price': '73.2263',
#          'buy_price': '72.5',
#          'closing_price': '72.5',
#          'max_price': '75.4',
#          'min_price': '72',
#          'opening_price': '72.8',
#          'sell_price': '73.6',
#          'units_traded': '2036135.87905356',
#          'volume_1day': '2036135.87905356',
#          'volume_7day': '21627007.06703651'},
#  'XLM': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-2.30',
#          'average_price': '128.0974',
#          'buy_price': '126',
#          'closing_price': '127',
#          'max_price': '131',
#          'min_price': '126',
#          'opening_price': '130',
#          'sell_price': '127',
#          'units_traded': '4707311.03395757',
#          'volume_1day': '4707311.03395757',
#          'volume_7day': '47647617.41654493'},
#  'XMR': {'24H_fluctate': '-1650',
#          '24H_fluctate_rate': '-2.88',
#          'average_price': '55884.8917',
#          'buy_price': '55300',
#          'closing_price': '55450',
#          'max_price': '57500',
#          'min_price': '55000',
#          'opening_price': '57100',
#          'sell_price': '55600',
#          'units_traded': '13958714.07889034',
#          'volume_1day': '13958714.07889034',
#          'volume_7day': '69301124.530824596036'},
#  'XRP': {'24H_fluctate': '-11',
#          '24H_fluctate_rate': '-2.67',
#          'average_price': '403.9578',
#          'buy_price': '400',
#          'closing_price': '400',
#          'max_price': '413',
#          'min_price': '397',
#          'opening_price': '411',
#          'sell_price': '401',
#          'units_traded': '45981053.43662905',
#          'volume_1day': '45981053.43662905',
#          'volume_7day': '472796500.12783077'},
#  'XVG': {'24H_fluctate': '-0.05',
#          '24H_fluctate_rate': '-0.63',
#          'average_price': '7.8667',
#          'buy_price': '7.75',
#          'closing_price': '7.86',
#          'max_price': '8.04',
#          'min_price': '7.72',
#          'opening_price': '7.91',
#          'sell_price': '7.85',
#          'units_traded': '5760535.02915987',
#          'volume_1day': '5760535.02915987',
#          'volume_7day': '51322346.83504364'},
#  'ZEC': {'24H_fluctate': '-2450',
#          '24H_fluctate_rate': '-3.64',
#          'average_price': '65681.6152',
#          'buy_price': '64800',
#          'closing_price': '64700',
#          'max_price': '67350',
#          'min_price': '64150',
#          'opening_price': '67150',
#          'sell_price': '64950',
#          'units_traded': '36204.40544304',
#          'volume_1day': '36204.40544304',
#          'volume_7day': '33202253.41142229'},
#  'ZIL': {'24H_fluctate': '-0.2',
#          '24H_fluctate_rate': '-0.89',
#          'average_price': '22.3656',
#          'buy_price': '22.2',
#          'closing_price': '22.2',
#          'max_price': '22.7',
#          'min_price': '22',
#          'opening_price': '22.4',
#          'sell_price': '22.3',
#          'units_traded': '19188983.25439869',
#          'volume_1day': '19188983.25439869',
#          'volume_7day': '457118882.086513354635'},
#  'ZRX': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '363.787',
#          'buy_price': '358',
#          'closing_price': '361',
#          'max_price': '370',
#          'min_price': '356',
#          'opening_price': '361',
#          'sell_price': '361',
#          'units_traded': '1010091.49335099',
#          'volume_1day': '1010091.49335099',
#          'volume_7day': '5923254.005981677377380573'},
#  'date': '1546569668481'}

# %%
# 아래에 코드를 작성하세요.
# for name in currency:
#     try:
#         money = float(currency[name]['opening_price'])
#         change = float(currency[name]['max_price']) - float(currency[name]['min_price'])
#         deff = money + change
#         if deff > float(currency[name]['max_price']):
#             print(f'{name} 상승장')
#         else:
#             print(f'{name} 하락장')
#     except TypeError:
#         continue

for key, value in currency.items():
    if type(value) == type(dict()):
        money = float(value['opening_price'])
        change = float(value['max_price']) - float(value['min_price'])
        deff = money + change
        if deff > float(value['max_price']):
            print(f'{key:5} 상승장')
        else:
            print(f'{key:5} 하락장')
# Out:
# BTC   상승장
# ETH   상승장
# DASH  상승장
# LTC   상승장
# ETC   상승장
# XRP   상승장
# BCH   상승장
# XMR   상승장
# ZEC   상승장
# QTUM  상승장
# BTG   상승장
# EOS   상승장
# ICX   상승장
# VET   상승장
# TRX   상승장
# ELF   상승장
# MITH  상승장
# MCO   상승장
# OMG   상승장
# KNC   상승장
# GNT   상승장
# ZIL   상승장
# ETHOS 상승장
# PAY   상승장
# WAX   상승장
# POWR  상승장
# LRC   상승장
# GTO   상승장
# STEEM 상승장
# STRAT 상승장
# ZRX   상승장
# REP   상승장
# AE    상승장
# XEM   상승장
# SNT   상승장
# ADA   상승장
# PPT   상승장
# CTXC  상승장
# CMT   상승장
# THETA 상승장
# WTC   상승장
# ITC   상승장
# TRUE  상승장
# ABT   상승장
# RNT   상승장
# PLY   상승장
# WAVES 상승장
# LINK  상승장
# ENJ   상승장
# PST   상승장
# SALT  상승장
# RDN   상승장
# LOOM  상승장
# BHPC  상승장
# PIVX  상승장
# INS   상승장
# BCD   상승장
# BZNT  상승장
# XLM   상승장
# OCN   상승장
# BSV   상승장
# TMTG  상승장
# BAT   상승장
# WET   상승장
# XVG   상승장
# IOST  상승장
# POLY  상승장
# HC    상승장
# ROM   상승장
# AMO   상승장
